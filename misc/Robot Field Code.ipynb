# %%
import math
import numpy as np
import array as arr
import matplotlib.pyplot as plt
#import pixy2 as pixy
#import serial

#serial.begin(115200)
#pixy.init()
blocks = 1

while blocks == 1:
    #pixy.ccc.getBlocks()
    blocks = 1
    initialAngle = 90
    armAngle = 103
    #x = 
    
    if(blocks == 1):                                           #makes sure there are objects on the field
        numBlocks = 2                                #assigns numBlocks the number of objects on the field
        block = arr.array('i',[1,2])
        for i in range(0, numBlocks):
            if(block[i] == 1):                    # 1 stands for die
                mode = 1                                                #mode 1 means cup and die
                obj = 1
                x = 160
                xtest = x
                y = 50
                
                if(x < armAngle):                               # left side of arm
                    dx = (103 - x)
                    dy = (y)
                    dieAngle = math.degrees(np.arctan2(dy,dx))
                    moveAngle = dieAngle - initialAngle    
                elif(x > armAngle):                           # right side of arm
                    dx = (x - 103)
                    dy = (y)
                    dieAngle = 180 - math.degrees(np.arctan2(dy,dx))
                    moveAngle = dieAngle - initialAngle
                else:                                        # down the center
                    dieAngle = 90
                    moveAngle = 0

                print("dieAngle = ", dieAngle)
                print("moveAngle = ", moveAngle)
                
                xtest = xtest -  103
                radius = math.sqrt(np.square(xtest) + np.square(y))         #finds radius of where the die is
                plt.plot([x],[y],'ro')
                
                print ("distance of die from arm: ", radius)
                if radius > 45 and radius < 55:
                    arc = 1
                elif radius > 70 and radius < 80:
                    arc = 2
                elif radius > 95 and radius < 105:
                    arc = 3
                    
                print("arc: ", arc)
                
                #Code below creates field
                R = 100
                R2 = 75
                R3 = 50
                n = 100
                t = np.linspace(0,2*np.pi,n)
                t2 = np.linspace(0,2*np.pi,n)
                t3 = np.linspace(0,2*np.pi,n)
                x2 = R*np.cos(t)+ 103
                y2 = R*np.sin(t)
                x3 = R2*np.cos(t)+ 103
                y3 = R2*np.sin(t)
                x4 = R3*np.cos(t)+ 103
                y4 = R3*np.sin(t)
                
                plt.scatter(103,0, s = 1000, c='yellow')
                
                plt.plot(x2,y2, 'black')
                plt.plot(x3,y3, 'black')
                plt.plot(x4,y4, 'black')
                plt.axis([0,206,0,206])
                plt.show()
                
                
    blocks = blocks + 1
# Out:
# dieAngle =  138.74298829568713
# moveAngle =  48.74298829568713
# distance of die from arm:  75.82216034906945
# arc:  2

# %%
peg1x = 51.5
peg2x = 103
peg3x = 154.5
pegy = 50

r1 = 5
r2 = 8
r3 = 11

class rings:
    def __init__(self, xaxis, size):
        self.xaxis = xaxis
        self.size = size
        

ring1 = rings(peg1x, 1)
ring2 = rings(peg1x, 2)
ring3 = rings(peg1x, 3)


#Plot generation
R = 100
R2 = 75
R3 = 50
n = 100
t = np.linspace(0,2*np.pi,n)
x2 = R*np.cos(t) + 103
y2 = R*np.sin(t)
x3 = R2*np.cos(t) + 103
y3 = R2*np.sin(t)
x4 = R3*np.cos(t) + 103
y4 = R3*np.sin(t)
rin1x = r1*np.cos(t) + peg1x
rin2x = r2*np.cos(t) + peg1x
rin3x = r3*np.cos(t) + peg1x
rin1y = r1*np.sin(t) + pegy
rin2y = r2*np.sin(t) + pegy
rin3y = r3*np.sin(t) + pegy


#n = int(input("Enter number of rings: "))
m = 3

def TowerOfHanoi(m , present, destination, aux): 
    global rin1x
    global rin2x
    global rin3x
    if m == 1: 
        print("Move ring 1 from ",present,"to ",destination)
        rin1x = rin1x + destination - present
        ########################
        plt.plot(rin1x,rin1y, 'black')
        plt.plot(rin2x,rin2y, 'black')
        plt.plot(rin3x,rin3y, 'black')               
        plt.scatter(103,0, s = 1000, c='yellow')
        plt.scatter(51.5,50, s = 1000, c='pink')
        plt.scatter(103,50, s = 1000, c='pink')
        plt.scatter(154.5,50, s = 1000, c='pink')               
        plt.plot(x2,y2, 'black')
        plt.plot(x3,y3, 'black')
        plt.plot(x4,y4, 'black')
        plt.axis([0,206,0,206])
        plt.show()
        ########################
        plt.pause(2)
        return
    TowerOfHanoi(m-1, present, aux, destination) 
    print("Move ring",m,"from ",present,"to ",destination)
    if(m == 2): 
        
        rin2x = rin2x + destination - present
        ########################
        plt.plot(rin1x,rin1y, 'black')
        plt.plot(rin2x,rin2y, 'black')
        plt.plot(rin3x,rin3y, 'black')               
        plt.scatter(103,0, s = 1000, c='yellow')
        plt.scatter(51.5,50, s = 1000, c='pink')
        plt.scatter(103,50, s = 1000, c='pink')
        plt.scatter(154.5,50, s = 1000, c='pink')               
        plt.plot(x2,y2, 'black')
        plt.plot(x3,y3, 'black')
        plt.plot(x4,y4, 'black')
        plt.axis([0,206,0,206])
        plt.show()
        ##################
        plt.pause(2)
    else:
        
        rin3x = rin3x + destination - present
        ########################
        plt.plot(rin1x,rin1y, 'black')
        plt.plot(rin2x,rin2y, 'black')
        plt.plot(rin3x,rin3y, 'black')               
        plt.scatter(103,0, s = 1000, c='yellow')
        plt.scatter(51.5,50, s = 1000, c='pink')
        plt.scatter(103,50, s = 1000, c='pink')
        plt.scatter(154.5,50, s = 1000, c='pink')               
        plt.plot(x2,y2, 'black')
        plt.plot(x3,y3, 'black')
        plt.plot(x4,y4, 'black')
        plt.axis([0,206,0,206])
        plt.show()
        ##################
        plt.pause(2)
    TowerOfHanoi(m-1, aux, destination, present) 


#Function call
TowerOfHanoi(m, peg1x, peg3x, peg2x)
# Out:
# Move ring 1 from  51.5 to  103
# Move ring 2 from  51.5 to  154.5
# Move ring 1 from  103 to  154.5

# %%
#Plot generation
R = 100
R2 = 75
R3 = 50
n = 100
t = np.linspace(0,2*np.pi,n)
x2 = R*np.cos(t) + 103
y2 = R*np.sin(t)
x3 = R2*np.cos(t) + 103
y3 = R2*np.sin(t)
x4 = R3*np.cos(t) + 103
y4 = R3*np.sin(t)
rin1x = r1*np.cos(t) + peg1x
rin2x = r2*np.cos(t) + peg1x
rin3x = r3*np.cos(t) + peg1x
rin1y = r1*np.sin(t) + pegy
rin2y = r2*np.sin(t) + pegy
rin3y = r3*np.sin(t) + pegy

plt.plot(rin1x,rin1y, 'black')
plt.plot(rin2x,rin2y, 'black')
plt.plot(rin3x,rin3y, 'black')               
plt.scatter(103,0, s = 1000, c='yellow')
plt.scatter(51.5,50, s = 1000, c='pink')
plt.scatter(103,50, s = 1000, c='pink')
plt.scatter(154.5,50, s = 1000, c='pink')               
plt.plot(x2,y2, 'black')
plt.plot(x3,y3, 'black')
plt.plot(x4,y4, 'black')
plt.axis([0,206,0,206])
plt.show()

# %%
peg1x = 51.5
peg2x = 103
peg3x = 154.5
pegy = 50

m = int(input("Enter the number of rings: "))
w = m

#Plot generation
R = 100
R2 = 75
R3 = 50
n = 100
t = np.linspace(0,2*np.pi,n)
x2 = R*np.cos(t) + 103
y2 = R*np.sin(t)
x3 = R2*np.cos(t) + 103
y3 = R2*np.sin(t)
x4 = R3*np.cos(t) + 103
y4 = R3*np.sin(t)

r1 = 2
ringx = []
for i in range(0, m):
    ringx.append(r1*np.cos(t) + peg1x)
    r1 = r1 + 2
    
r2 = 2
ringy = []
for i in range(0, m):
    ringy.append(r2*np.sin(t) + pegy)
    r2 = r2 + 2
    
for i in range(0, m):
    plt.plot(ringx[i], ringy[i], 'black')
    plt.scatter(103,0, s = 1000, c='yellow')
    plt.scatter(51.5,50, s = 1000, c='pink')
    plt.scatter(103,50, s = 1000, c='pink')
    plt.scatter(154.5,50, s = 1000, c='pink')               
    plt.plot(x2,y2, 'black')
    plt.plot(x3,y3, 'black')
    plt.plot(x4,y4, 'black')
plt.axis([0,206,0,206])
plt.show()
plt.pause(2)


def TowerOfHanoi(m , present, destination, aux): 
    if m == 1: 
        print("Move ring 1 from ",present,"to ",destination)
        ringx[0] = ringx[0] + destination - present
        ######################## Plot generation
        for i in range(0, w):
            plt.plot(ringx[i], ringy[i], 'black')
            plt.scatter(103,0, s = 1000, c='yellow')
            plt.scatter(51.5,50, s = 1000, c='pink')
            plt.scatter(103,50, s = 1000, c='pink')
            plt.scatter(154.5,50, s = 1000, c='pink')               
            plt.plot(x2,y2, 'black')
            plt.plot(x3,y3, 'black')
            plt.plot(x4,y4, 'black')
        plt.axis([0,206,0,206])
        plt.show()
        plt.pause(2)
        ########################
        return
    TowerOfHanoi(m-1, present, aux, destination) 
    print("Move ring",m,"from ",present,"to ",destination)
    ringx[m-1] = ringx[m-1] + destination - present
    ########################Plot Generation
    for i in range(0, w):
        plt.plot(ringx[i], ringy[i], 'black')                
        plt.scatter(103,0, s = 1000, c='yellow')
        plt.scatter(51.5,50, s = 1000, c='pink')
        plt.scatter(103,50, s = 1000, c='pink')
        plt.scatter(154.5,50, s = 1000, c='pink')               
        plt.plot(x2,y2, 'black')
        plt.plot(x3,y3, 'black')
        plt.plot(x4,y4, 'black')
    plt.axis([0,206,0,206])
    plt.show()
    plt.pause(2)
    ########################
    
    TowerOfHanoi(m-1, aux, destination, present) 


#Function call
TowerOfHanoi(m, peg1x, peg3x, peg2x)
# Out:
# Enter the number of rings: 7
# Move ring 1 from  51.5 to  154.5
# Move ring 2 from  51.5 to  103
# Move ring 1 from  154.5 to  103
# Move ring 3 from  51.5 to  154.5
# Move ring 1 from  103 to  51.5
# Move ring 2 from  103 to  154.5
# Move ring 1 from  51.5 to  154.5
# Move ring 4 from  51.5 to  103
# Move ring 1 from  154.5 to  103
# Move ring 2 from  154.5 to  51.5
# Move ring 1 from  103 to  51.5
# Move ring 3 from  154.5 to  103
# Move ring 1 from  51.5 to  154.5
# Move ring 2 from  51.5 to  103
# Move ring 1 from  154.5 to  103
# Move ring 5 from  51.5 to  154.5
# Move ring 1 from  103 to  51.5
# Move ring 2 from  103 to  154.5
# Move ring 1 from  51.5 to  154.5
# Move ring 3 from  103 to  51.5
# Move ring 1 from  154.5 to  103
# Move ring 2 from  154.5 to  51.5
# Move ring 1 from  103 to  51.5
# Move ring 4 from  103 to  154.5
# Move ring 1 from  51.5 to  154.5
# Move ring 2 from  51.5 to  103
# Move ring 1 from  154.5 to  103
# Move ring 3 from  51.5 to  154.5
# ...

# %%
# Out:
# 2
